# %%
import graphviz

# %%
g = graphviz.Digraph(name='00', directory='graph/00')

# %%
g.node('test')
g

# %%
for i in range(10):
    g.node('test%d'%i)
g

# %%
g.edge('test0', 'test1')
g

# %%
g.edges([('test0', 'test2'),
         ('test0', 'test3'),
        ])
g

# %%
g.body
# Out:
# ['\ttest',
#  '\ttest0',
#  '\ttest1',
#  '\ttest2',
#  '\ttest3',
#  '\ttest4',
#  '\ttest5',
#  '\ttest6',
#  '\ttest7',
#  '\ttest8',
#  '\ttest9',
#  '\ttest0 -> test1',
#  '\ttest0 -> test2',
#  '\ttest0 -> test3']

# %%
print(g.source)
# Out:
# digraph 00 {
# 	test
# 	test0
# 	test1
# 	test2
# 	test3
# 	test4
# 	test5
# 	test6
# 	test7
# 	test8
# 	test9
# 	test0 -> test1
# 	test0 -> test2
# 	test0 -> test3
# }

# %%
g.edges([('test%d'%i, 'test%d'%(i+1)) for i in range(10)])

# %%
g.graph_attr['rankdir'] = 'LR'

# %%
g

# %%
g.edges([('test', 'test%d'%i) for i in range(10)])
g

# %%
g.node_attr.update({'shape': 'box'})
g.node_attr
# Out:
# {'shape': 'box'}

# %%
g.node_attr.update({'shape': 'circle'})
g.node_attr
# Out:
# {'shape': 'circle'}

# %%
g

# %%
g = graphviz.Digraph(name='00', directory='graph/00',
                     graph_attr={'rankdir': 'LR',
                                 'splines': 'spline'})

# %%
g.node('Y', shape='circle', fontcolor='white', style='filled', fillcolor='black')
g

# %%
g.node('V', shape='circle', fontcolor='white', style='filled', fillcolor='black')
g

# %%
g.edge_attr.update(arrowhead='none')

# %%
g.edge('Y', 'V')

# %%
g

# %%
g.edge('Y', 'V')
g

# %%
g.edges([('Y', 'V') for i in range(18)])

# %%
g

# %%
text = 'ICTOR'

# %%
for t in text:
    g.node(t, shape='circle', fontcolor='white', style='filled', fillcolor='black')

# %%
g.edges([('V', 'I') for i in range(20)])

# %%
g

# %%
for ind, txt in enumerate(text):
    try:
        g.edges([(text[ind], text[ind+1]) for i in range(20)])
    except:
        pass

# %%
g

# %%
! echo $DOTFONTPATH
